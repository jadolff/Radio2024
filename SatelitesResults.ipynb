# %%
from SatImports import *
# %load_ext autoreload
# %autoreload 2

# %%
file = 'Daten Nacht 09/ETH_20240110_033002_01.fit'
data, t, freq = read_in_data(file)
plt.figure( figsize=(16, 8) )
plt.imshow(data, aspect='auto', extent=[t[0],t[-1],freq[-1],freq[0]])

# p01 = (S0, omega, a, b)
# p02 = (V0, omega, phi)
p01 = np.array([12.5, 0.0045, 0.0, 60.0])
p02 = np.array([0.0045, 0.0])
#fit_sat(data, ([70, 80], [2400, 3000]), t, freq, p01, p02)

print("")
print("-------------------------")
print("This is GLOBALSTAR M014!!")
# Out:
# -------------------------
# This is GLOBALSTAR M014!!

# %%
file = 'Daten Nacht 09/ETH_20240109_190531_01.fit'
data, t, freq = read_in_data(file)

# p01 = (S0, omega, a, b)
# p02 = (V0, omega, phi)
p01 = np.array([12.5, 0.002, 0.0, 60.0])
p02 = np.array([0.002, 0.0])
fit_sat(data, ([165, 180], [500, 1000]), t, freq, p01, p02)

print("")
print("-------------------------")
print("This is GLOBALSTAR M023!!")
# Out:
# /Users/juliusadolff/Desktop/Interferometer 2024/Radio2024/SatImports.py:76: RuntimeWarning: divide by zero encountered in divide
#   data_pure = (data[fpos, :] - params[2] * t - params[3])/( params[0] * np.exp(- params[1]**2 * (t - tmax)**2 / (2 * 0.065**2) ) )
# /Users/juliusadolff/Desktop/Interferometer 2024/Radio2024/SatImports.py:76: RuntimeWarning: overflow encountered in divide
#   data_pure = (data[fpos, :] - params[2] * t - params[3])/( params[0] * np.exp(- params[1]**2 * (t - tmax)**2 / (2 * 0.065**2) ) )
# Angular Velocity of Satelite from our PoV: omega ~ 0.00502 ± 5.84e-05 1/s
# Velocity of Satelite: vr ~ 7.15e+03 m/s
# Period of Satelite: T ~ 6.85e+03 s = 1.14e+02 min
# Height of Salelite: h ~ 1.43e+06 m
#
# -------------------------
# This is GLOBALSTAR M023!!
