# %%
from SatImports import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
file = 'Nacht 08/ETH_20240109_024501_01.fit'
data, t, freq = read_in_data(file)

# p01 = (S0, omega, a, b)
# p02 = (omega, phi)
p01 = np.array([12.5, 0.003, 0.0, 60.0])
p02 = np.array([0.003, 4.31])
fit_sat(data, ([70, 80], [1000, 2000]), t, freq, p01, p02)
# Out:
# Angular Velocity of Satelite from our PoV: omega ~ 0.0026 ± 2.91e-05 1/s
# Velocity of Satelite: vr ~ 6.68e+03 m/s
# Period of Satelite: T ~ 8.41e+03 s = 1.4e+02 min
# Height of Salelite: h ~ 2.57e+06 m

# %%
file = 'Nacht 08/ETH_20240109_071504_01.fit'
data, t, freq = read_in_data(file)

# p01 = (S0, omega, a, b)
# p02 = (V0, omega, phi)
p01 = np.array([12.5, 0.003, 0.0, 60.0])
p02 = np.array([0.003, 0.0])
fit_sat(data, ([70, 80], [1500, 2500]), t, freq, p01, p02)
# Out:
# Angular Velocity of Satelite from our PoV: omega ~ 0.00275 ± 4.93e-05 1/s
# Velocity of Satelite: vr ~ 6.72e+03 m/s
# Period of Satelite: T ~ 8.24e+03 s = 1.37e+02 min
# Height of Salelite: h ~ 2.45e+06 m
