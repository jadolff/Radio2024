# %%
from SatImports import *
#from SatImports_MC import*
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
file = 'Daten Nacht 09/ETH_20240110_033002_01.fit'
data, t, freq = read_in_data(file)

# p01 = (S0, omega, a, b)
# p02 = (V0, omega, phi)
p01 = np.array([12.5, 0.0045, 0.0, 60.0])
p02 = np.array([0.0045, 0.0])
fit_sat(data, ([70, 80], [2400, 3000]), t, freq, p01, p02)

print("")
print("-------------------------")
print("This is GLOBALSTAR M014!!")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:195: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:199: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims)
# Angular Velocity of Satelite from our PoV: omega ~ 0.00442 ± 4.45e-07 1/s
# Velocity of Satelite: vr ~ 7.07e+03 m/s
# Period of Satelite: T ~ 7.08e+03 s = 1.18e+02 min
# Height of Salelite: h ~ 1.6e+06 m
#
# -------------------------
# This is GLOBALSTAR M014!!

# %%
file = 'Daten Nacht 09/ETH_20240109_190531_01.fit'
data, t, freq = read_in_data(file)

# p01 = (S0, omega, a, b)
# p02 = (V0, omega, phi)
p01 = np.array([12.5, 0.002, 0.0, 60.0])
p02 = np.array([0.002, 0.0])
fit_sat(data, ([165, 180], [500, 1000]), t, freq, p01, p02)

print("")
print("-------------------------")
print("This is GLOBALSTAR M023!!")
# Out:
# /Users/tino/Desktop/Astrowoche/Radio2024/SatImports_MC.py:64: RuntimeWarning: divide by zero encountered in true_divide
#   mc_data[i, :] = ( data - N(t, a[i], b[i]) ) / model(t, S0[i], omega[i])
# /Users/tino/Desktop/Astrowoche/Radio2024/SatImports_MC.py:64: RuntimeWarning: overflow encountered in true_divide
#   mc_data[i, :] = ( data - N(t, a[i], b[i]) ) / model(t, S0[i], omega[i])
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:195: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:199: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:151: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:183: RuntimeWarning: overflow encountered in reduce
#   arrmean = umr_sum(arr, axis, dtype, keepdims=True)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:193: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:151: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:183: RuntimeWarning: invalid value encountered in reduce
#   arrmean = umr_sum(arr, axis, dtype, keepdims=True)
# Angular Velocity of Satelite from our PoV: omega ~ 0.00237 ± 3.38e-06 1/s
# Velocity of Satelite: vr ~ 6.6e+03 m/s
# Period of Satelite: T ~ 8.71e+03 s = 1.45e+02 min
# Height of Salelite: h ~ 2.78e+06 m
#
# -------------------------
# This is GLOBALSTAR M023!!
